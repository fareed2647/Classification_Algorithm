# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import pandas as pd

# %%
data=pd.read_csv("C:/Users/HP/OneDrive/Desktop/Internship/xlsheets/cardio_train.csv")

# %%
data.head()
# Out:
#   id;age;gender;height;weight;ap_hi;ap_lo;cholesterol;gluc;smoke;alco;active;cardio
# 0              0;18393;2;168;62.0;110;80;1;1;0;0;1;0
# 1              1;20228;1;156;85.0;140;90;3;1;0;0;1;1
# 2              2;18857;1;165;64.0;130;70;3;1;0;0;0;1
# 3             3;17623;2;169;82.0;150;100;1;1;0;0;1;1
# 4              4;17474;1;156;56.0;100;60;1;1;0;0;0;0

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = 'C:/Users/HP/OneDrive/Desktop/Internship/xlsheets/cardio_train.csv'

# Load the CSV file with the correct delimiter
data= pd.read_csv(file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(data.head())
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
data.shape
# Out:
# (70000, 13)

# %%
data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
data.columns=['ID','Age','Gender','Height','Weight','systolic_High','Diastolic_Low','Cholesterol','Glucose','Smoke','Alc_consumptn','Active','Cardio']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             70000 non-null  int64
#  1   Age            70000 non-null  int64
#  2   Gender         70000 non-null  int64
#  3   Height         70000 non-null  int64
#  4   Weight         70000 non-null  float64
#  5   systolic_High  70000 non-null  int64
#  6   Diastolic_Low  70000 non-null  int64
#  7   Cholesterol    70000 non-null  int64
#  8   Glucose        70000 non-null  int64
#  9   Smoke          70000 non-null  int64
#  10  Alc_consumptn  70000 non-null  int64
#  11  Active         70000 non-null  int64
#  12  Cardio         70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
data.duplicated().value_counts()
# Out:
# False    70000
# Name: count, dtype: int64

# %%
data=data.drop('ID',axis=1)

# %%
data.shape
# Out:
# (70000, 12)

# %%
num=data.select_dtypes(include='number')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# figure,axes=plt.subplots(8,2,figsize=(15,30))
# i=0
# color=["#FF0000", "#0000FF", "#008000", "#FFFF00", "#800080", "#FFA500", "#00FFFF", "#FF00FF"]
# for col in num:
#     sns.barplot(data[col],orient='h',ax=axes[i][1],color=color[i])
#     sns.histplot(data[col],ax=axes[i][2],color=color[i])
#     i=i+1

# %%
y=data['Cardio']
data=data.drop(['Cardio'],axis=1)

# %% [markdown]
# ## SCALING

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
data=ss.fit_transform(data)

# %%
data=pd.DataFrame(data)

# %%
data.columns=['Age','Gender','Height','Weight','systolic_High','Diastolic_Low','Cholesterol','Glucose','Smoke','Alc_consumptn','Active']

# %%
data.head()
# Out:
#         Age    Gender    Height    Weight  systolic_High  Diastolic_Low  \
# 0 -0.436062  1.364055  0.443452 -0.847873      -0.122182      -0.088238
# 1  0.307686 -0.733108 -1.018168  0.749831       0.072610      -0.035180
# 2 -0.247997 -0.733108  0.078047 -0.708942       0.007679      -0.141297
# 3 -0.748152  1.364055  0.565254  0.541435       0.137541       0.017879
# 4 -0.808543 -0.733108 -1.018168 -1.264666      -0.187113      -0.194356
#
#    Cholesterol  Glucose     Smoke  Alc_consumptn    Active
# 0    -0.539322 -0.39572 -0.310879      -0.238384  0.494167
# 1     2.400793 -0.39572 -0.310879      -0.238384  0.494167
# 2     2.400793 -0.39572 -0.310879      -0.238384 -2.023607
# 3    -0.539322 -0.39572 -0.310879      -0.238384  0.494167
# 4    -0.539322 -0.39572 -0.310879      -0.238384 -2.023607

# %% [markdown]
# ## TRAIN TEST SPLIT

# %%
x=data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=3)

# %% [markdown]
# # BUILDING ML MODELS
# ## RANDOMFOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
RFC = RandomForestClassifier(n_estimators=1000,random_state=2,criterion= "gini")
RFC.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=2)

# %%
y_train_pred = RFC.predict(x_train)

# %%
from sklearn.metrics import accuracy_score, precision_score
acc_score = accuracy_score(y_train, y_train_pred)
print('Accuracy score :', acc_score)
pre_score = precision_score(y_train, y_train_pred, average='weighted')
print('Precision score :', pre_score)
# Out:
# Accuracy score : 0.9997551020408163
# Precision score : 0.9997551322023799

# %%
y_test_pred = RFC.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score
acc_score = accuracy_score(y_test, y_test_pred)
print('Accuracy score :', acc_score)
pre_score = precision_score(y_test, y_test_pred, average='weighted')
print('Precision score :', pre_score)
# Out:
# Accuracy score : 0.7136666666666667
# Precision score : 0.7136749518618202

# %% [markdown]
# ## SVC CLASSIFIER

# %%
from sklearn.svm import SVC
import numpy as np
svc_model = SVC(kernel='rbf',degree = 3, C=1.0, gamma='scale')
svc_model.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_train_pred = svc_model.predict(x_train)

# %%
from sklearn.metrics import accuracy_score, precision_score
acc_score = accuracy_score(y_train, y_train_pred)
print('Accuracy score :', acc_score)
pre_score = precision_score(y_train, y_train_pred, average='weighted')
print('Precision score :', pre_score)
# Out:
# Accuracy score : 0.7326530612244898
# Precision score : 0.7336761598746036

# %%
y_test_pred = svc_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score
acc_score = accuracy_score(y_test, y_test_pred)
print('Accuracy score :', acc_score)
pre_score = precision_score(y_test, y_test_pred, average='weighted')
print('Precision score :', pre_score)
# Out:
# Accuracy score : 0.7264761904761905
# Precision score : 0.7267771757970978

# %% [markdown]
# ## LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_train_pred = log_reg.predict(x_train)

# %%
from sklearn.metrics import accuracy_score, precision_score
acc_score = accuracy_score(y_train, y_train_pred)
print('Accuracy score :', acc_score)
pre_score = precision_score(y_train, y_train_pred, average='weighted')
print('Precision score :', pre_score)
# Out:
# Accuracy score : 0.7188163265306122
# Precision score : 0.7203140421784249

# %%
y_test_pred = log_reg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score
acc_score = accuracy_score(y_test, y_test_pred)
print('Accuracy score :', acc_score)
pre_score = precision_score(y_test, y_test_pred, average='weighted')
print('Precision score :', pre_score)
# Out:
# Accuracy score : 0.7171904761904762
# Precision score : 0.7176872452442886

# %% [markdown]
# ## XGB CLASSIFIER

# %%
from xgboost import XGBClassifier
xgb_clf = XGBClassifier(maxdepth=4,learning_rate=1.0,n_estimators=100)
xgb_clf.fit(x_train,y_train)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [16:56:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-06abd128ca6c1688d-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "maxdepth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=1.0, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None, maxdepth=4,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_train_pred = xgb_clf.predict(x_train)

# %%
from sklearn.metrics import accuracy_score, precision_score
acc_score = accuracy_score(y_train, y_train_pred)
print('Accuracy score :', acc_score)
pre_score = precision_score(y_train, y_train_pred, average='weighted')
print('Precision score :', pre_score)
# Out:
# Accuracy score : 0.8111224489795918
# Precision score : 0.8127174357785086

# %%
y_test_pred = xgb_clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score
acc_score = accuracy_score(y_test, y_test_pred)
print('Accuracy score :', acc_score)
pre_score = precision_score(y_test, y_test_pred, average='weighted')
print('Precision score :', pre_score)
# Out:
# Accuracy score : 0.7064285714285714
# Precision score : 0.7067820228529537
