# %%
import pandas as pd
# Out:
# C:\Users\mdbab\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data = pd.read_csv('C://Users//mdbab//OneDrive//Desktop//DATA SCIENCE MATERIAL//DATA//nasa.csv')

# %%
data.head()
# Out:
#    Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0           3703080  3703080                21.6            0.127220
# 1           3723955  3723955                21.3            0.146068
# 2           2446862  2446862                20.3            0.231502
# 3           3092506  3092506                27.4            0.008801
# 4           3514799  3514799                21.6            0.127220
#
#    Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# 0            0.284472         127.219879         284.472297
# 1            0.326618         146.067964         326.617897
# 2            0.517654         231.502122         517.654482
# 3            0.019681           8.801465          19.680675
# 4            0.284472         127.219879         284.472297
#
#    Est Dia in Miles(min)  Est Dia in Miles(max)  Est Dia in Feet(min)  ...  \
# 0               0.079051               0.176763            417.388066  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4687 entries, 0 to 4686
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Neo Reference ID              4687 non-null   int64
#  1   Name                          4687 non-null   int64
#  2   Absolute Magnitude            4687 non-null   float64
#  3   Est Dia in KM(min)            4687 non-null   float64
#  4   Est Dia in KM(max)            4687 non-null   float64
#  5   Est Dia in M(min)             4687 non-null   float64
#  6   Est Dia in M(max)             4687 non-null   float64
#  7   Est Dia in Miles(min)         4687 non-null   float64
#  8   Est Dia in Miles(max)         4687 non-null   float64
#  9   Est Dia in Feet(min)          4687 non-null   float64
#  10  Est Dia in Feet(max)          4687 non-null   float64
#  11  Close Approach Date           4687 non-null   object
# ...

# %%
data.columns
# Out:
# Index(['Neo Reference ID', 'Name', 'Absolute Magnitude', 'Est Dia in KM(min)',
#        'Est Dia in KM(max)', 'Est Dia in M(min)', 'Est Dia in M(max)',
#        'Est Dia in Miles(min)', 'Est Dia in Miles(max)',
#        'Est Dia in Feet(min)', 'Est Dia in Feet(max)', 'Close Approach Date',
#        'Epoch Date Close Approach', 'Relative Velocity km per sec',
#        'Relative Velocity km per hr', 'Miles per hour',
#        'Miss Dist.(Astronomical)', 'Miss Dist.(lunar)',
#        'Miss Dist.(kilometers)', 'Miss Dist.(miles)', 'Orbiting Body',
#        'Orbit ID', 'Orbit Determination Date', 'Orbit Uncertainity',
#        'Minimum Orbit Intersection', 'Jupiter Tisserand Invariant',
#        'Epoch Osculation', 'Eccentricity', 'Semi Major Axis', 'Inclination',
#        'Asc Node Longitude', 'Orbital Period', 'Perihelion Distance',
#        'Perihelion Arg', 'Aphelion Dist', 'Perihelion Time', 'Mean Anomaly',
#        'Mean Motion', 'Equinox', 'Hazardous'],
#       dtype='object')

# %%
data = data.drop(columns=['Neo Reference ID','Miss Dist.(kilometers)', 'Miss Dist.(miles)','Miss Dist.(lunar)','Relative Velocity km per sec','Epoch Date Close Approach','Est Dia in Miles(min)','Est Dia in Miles(max)', 'Est Dia in Feet(min)', 'Est Dia in Feet(max)','Name','Est Dia in KM(min)', 'Est Dia in KM(max)','Equinox','Orbiting Body','Close Approach Date','Orbit Determination Date'])

# %%
data.columns
# Out:
# Index(['Absolute Magnitude', 'Est Dia in M(min)', 'Est Dia in M(max)',
#        'Relative Velocity km per hr', 'Miles per hour',
#        'Miss Dist.(Astronomical)', 'Orbit ID', 'Orbit Uncertainity',
#        'Minimum Orbit Intersection', 'Jupiter Tisserand Invariant',
#        'Epoch Osculation', 'Eccentricity', 'Semi Major Axis', 'Inclination',
#        'Asc Node Longitude', 'Orbital Period', 'Perihelion Distance',
#        'Perihelion Arg', 'Aphelion Dist', 'Perihelion Time', 'Mean Anomaly',
#        'Mean Motion', 'Hazardous'],
#       dtype='object')

# %%
data.shape
# Out:
# (4687, 23)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4687 entries, 0 to 4686
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Absolute Magnitude           4687 non-null   float64
#  1   Est Dia in M(min)            4687 non-null   float64
#  2   Est Dia in M(max)            4687 non-null   float64
#  3   Relative Velocity km per hr  4687 non-null   float64
#  4   Miles per hour               4687 non-null   float64
#  5   Miss Dist.(Astronomical)     4687 non-null   float64
#  6   Orbit ID                     4687 non-null   int64
#  7   Orbit Uncertainity           4687 non-null   int64
#  8   Minimum Orbit Intersection   4687 non-null   float64
#  9   Jupiter Tisserand Invariant  4687 non-null   float64
#  10  Epoch Osculation             4687 non-null   float64
#  11  Eccentricity                 4687 non-null   float64
# ...

# %%
data['Hazardous'] = data['Hazardous'].replace({'True':1,'False':0})

# %%
data['Hazardous'] = data['Hazardous'].astype(int)

# %%
data['Hazardous'].unique()
# Out:
# array([1, 0])

# %%
data.head()
# Out:
#    Absolute Magnitude  Est Dia in M(min)  Est Dia in M(max)  \
# 0                21.6         127.219879         284.472297
# 1                21.3         146.067964         326.617897
# 2                20.3         231.502122         517.654482
# 3                27.4           8.801465          19.680675
# 4                21.6         127.219879         284.472297
#
#    Relative Velocity km per hr  Miles per hour  Miss Dist.(Astronomical)  \
# 0                 22017.003799    13680.509944                  0.419483
# 1                 65210.346095    40519.173105                  0.383014
# 2                 27326.560182    16979.661798                  0.050956
# 3                 40225.948191    24994.839864                  0.285322
# 4                 35426.991794    22012.954985                  0.407832
#
#    Orbit ID  Orbit Uncertainity  Minimum Orbit Intersection  \
# 0        17                   5                    0.025282
# ...

# %%
data.shape
# Out:
# (4687, 23)

# %%
import matplotlib.pyplot as plt

# %%
# Checking of outliers through boxplots
plt.figure(figsize=(10,100))
for i, column in enumerate(data.columns, 1):
    plt.subplot(len(data.columns),1, i)  
    plt.boxplot(data[column])
    plt.title(column)

# %%
data.shape
# Out:
# (4687, 23)

# %%
num = data.select_dtypes(include=['number'])
num.head()
# Out:
#    Absolute Magnitude  Est Dia in M(min)  Est Dia in M(max)  \
# 0                21.6         127.219879         284.472297
# 1                21.3         146.067964         326.617897
# 2                20.3         231.502122         517.654482
# 3                27.4           8.801465          19.680675
# 4                21.6         127.219879         284.472297
#
#    Relative Velocity km per hr  Miles per hour  Miss Dist.(Astronomical)  \
# 0                 22017.003799    13680.509944                  0.419483
# 1                 65210.346095    40519.173105                  0.383014
# 2                 27326.560182    16979.661798                  0.050956
# 3                 40225.948191    24994.839864                  0.285322
# 4                 35426.991794    22012.954985                  0.407832
#
#    Orbit ID  Orbit Uncertainity  Minimum Orbit Intersection  \
# 0        17                   5                    0.025282
# ...

# %%
for k,v in data.items():
    q1 = v.quantile(0.25)
    q3 = v.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    v_col = v[(v >= lower_bound) & (v <= upper_bound)]

    # Dropping outliers from the original DataFrame
    data = data[data[k].isin(v_col)]

# %%
data.shape
# Out:
# (2707, 23)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2707 entries, 1 to 4685
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Absolute Magnitude           2707 non-null   float64
#  1   Est Dia in M(min)            2707 non-null   float64
#  2   Est Dia in M(max)            2707 non-null   float64
#  3   Relative Velocity km per hr  2707 non-null   float64
#  4   Miles per hour               2707 non-null   float64
#  5   Miss Dist.(Astronomical)     2707 non-null   float64
#  6   Orbit ID                     2707 non-null   int64
#  7   Orbit Uncertainity           2707 non-null   int64
#  8   Minimum Orbit Intersection   2707 non-null   float64
#  9   Jupiter Tisserand Invariant  2707 non-null   float64
#  10  Epoch Osculation             2707 non-null   float64
#  11  Eccentricity                 2707 non-null   float64
#  12  Semi Major Axis              2707 non-null   float64
# ...

# %%
data.columns
# Out:
# Index(['Absolute Magnitude', 'Est Dia in M(min)', 'Est Dia in M(max)',
#        'Relative Velocity km per hr', 'Miles per hour',
#        'Miss Dist.(Astronomical)', 'Orbit ID', 'Orbit Uncertainity',
#        'Minimum Orbit Intersection', 'Jupiter Tisserand Invariant',
#        'Epoch Osculation', 'Eccentricity', 'Semi Major Axis', 'Inclination',
#        'Asc Node Longitude', 'Orbital Period', 'Perihelion Distance',
#        'Perihelion Arg', 'Aphelion Dist', 'Perihelion Time', 'Mean Anomaly',
#        'Mean Motion', 'Hazardous'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
M_scaler = MinMaxScaler()

# %%
data= M_scaler.fit_transform(data)

# %%
data = pd.DataFrame(data)

# %%
data.columns = ['Absolute Magnitude', 'Est Dia in M(min)', 'Est Dia in M(max)',
       'Relative Velocity km per hr', 'Miles per hour',
       'Miss Dist.(Astronomical)', 'Orbit ID', 'Orbit Uncertainity',
       'Minimum Orbit Intersection', 'Jupiter Tisserand Invariant',
       'Epoch Osculation', 'Eccentricity', 'Semi Major Axis', 'Inclination',
       'Asc Node Longitude', 'Orbital Period', 'Perihelion Distance',
       'Perihelion Arg', 'Aphelion Dist', 'Perihelion Time', 'Mean Anomaly',
       'Mean Motion', 'Hazardous']

# %%
data.head()
# Out:
#    Absolute Magnitude  Est Dia in M(min)  Est Dia in M(max)  \
# 0               0.240           0.248813           0.248813
# 1               0.728           0.012011           0.012011
# 2               0.104           0.548112           0.548112
# 3               0.104           0.548112           0.548112
# 4               0.072           0.659617           0.659617
#
#    Relative Velocity km per hr  Miles per hour  Miss Dist.(Astronomical)  \
# 0                     0.555673        0.555673                  0.766334
# 1                     0.338757        0.338757                  0.570601
# 2                     0.327348        0.327348                  0.785909
# 3                     0.327348        0.327348                  0.785906
# 4                     0.752829        0.752829                  0.257757
#
#    Orbit ID  Orbit Uncertainity  Minimum Orbit Intersection  \
# 0  0.317460            0.428571                    0.651841
# ...

# %%
data.describe()
# Out:
#        Absolute Magnitude  Est Dia in M(min)  Est Dia in M(max)  \
# count         2707.000000        2707.000000        2707.000000
# mean             0.400262           0.182358           0.182358
# std              0.207299           0.202003           0.202003
# min              0.000000           0.000000           0.000000
# 25%              0.232000           0.038647           0.038647
# 50%              0.392000           0.101873           0.101873
# 75%              0.552000           0.260689           0.260689
# max              1.000000           1.000000           1.000000
#
#        Relative Velocity km per hr  Miles per hour  Miss Dist.(Astronomical)  \
# count                  2707.000000     2707.000000               2707.000000
# mean                      0.379813        0.379813                  0.511329
# std                       0.193022        0.193022                  0.284051
# min                       0.000000        0.000000                  0.000000
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
y=data['Hazardous']

# %%
x=data.drop(columns=['Hazardous'])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=32,stratify=y)

# %%
import xgboost as xg

# %%
from xgboost import XGBClassifier

# %%
XGBC = XGBClassifier(objective='binary:logistic',n_estimators = 30, max_depth= 3, learning_rate= 0.1)

# %%
XGBC.fit(Xtrain,Ytrain)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=30, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score,confusion_matrix

# %%
y_train_pred = XGBC.predict(x_train)
y_test_pred = XGBC.predict(x_test)

# %%
acc_train_score = accuracy_score(y_train, y_train_pred)
acc_test_score = accuracy_score(y_test, y_test_pred)
pre_train_score = precision_score(y_train, y_train_pred, average='weighted')
pre_test_score = precision_score(y_test, y_test_pred, average='weighted')
train_re_call = recall_score(y_train, y_train_pred, average='weighted')
test_re_call = recall_score(y_test, y_test_pred, average='weighted')
train_con_mat = confusion_matrix(y_train, y_train_pred)
test_con_mat = confusion_matrix(y_test, y_test_pred)


print('Train Accuracy score-------->',acc_train_score)
print('Test Accuracy score-------->',acc_test_score)
print('Train Precision score-------->',pre_train_score)
print('Test Precisoin score-------->',pre_test_score)
print('Train Recall score-------->',train_re_call)
print('Test Recall score-------->',test_re_call)
print('Train Confusion matrix-------->',train_con_mat)
print('Test Confusion matrix-------->',test_con_mat)
# Out:
# Train Accuracy score--------> 1.0
# Test Accuracy score--------> 1.0
# Train Precision score--------> 1.0
# Test Precisoin score--------> 1.0
# Train Recall score--------> 1.0
# Test Recall score--------> 1.0
# Train Confusion matrix--------> [[2030]]
# Test Confusion matrix--------> [[677]]
# C:\Users\mdbab\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# C:\Users\mdbab\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
